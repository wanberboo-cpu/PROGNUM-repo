# %% [markdown]
# Answers for week 1
#
# * name: Wander Berend Boomsma
# * Username: wbboomsma
# * Student s-number: S6121977
# * Group (AS1, etc...): AS3

# %%
x=22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi=22/7 # processed on Jupyter Hub

# %% [markdown]
# ![dog.jpg](attachment:dog.jpg)

# %%
6*5*4*3*2*1
# Out:
# 720

# %%
import math

import scipy.constants as const

print ("Gravitational Constant:",const.G)

m=7.3428*(10**22)
M=5.9722*(10**24)
r=385000600

F=(const.G*m*M)/(r**2)
print ("gravitational Force:",F,"newtons")
# Out:
# Gravitational Constant: 6.6743e-11
# gravitational Force: 1.9745991849104654e+20 newtons
